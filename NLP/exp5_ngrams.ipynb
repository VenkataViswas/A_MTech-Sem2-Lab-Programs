# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkataViswas/MTech-Sem2-Lab-Programs/blob/main/NLP/exp5_ngrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXPERIMENT-5
# N-Gram Model

# %%
from nltk import ngrams
s = "Hello Welcome to Python Programs"
n = 2
s = s.split()
result = ngrams(s, n)
for itr in result:
  print(itr)
# Out:
# ('Hello', 'Welcome')
# ('Welcome', 'to')
# ('to', 'Python')
# ('Python', 'Programs')

# %%
from nltk import ngrams
s = input("enter string s ")
n = int(input("Enter the n for n gram value : "))
s = s.split()
result = ngrams(s,n)
result
# Out:
# enter string s this is an mtech class from gitam university
# Enter the n for n gram value : 2
# <generator object ngrams at 0x7f66bbb65d40>

# %%
for r in result :
  print(r)
# Out:
# ('this', 'is')
# ('is', 'an')
# ('an', 'mtech')
# ('mtech', 'class')
# ('class', 'from')
# ('from', 'gitam')
# ('gitam', 'university')
