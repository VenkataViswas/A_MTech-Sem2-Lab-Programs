# %%
import nltk
from nltk.stem import PorterStemmer

words = ["gitam", "university", "sunflower", "beautiful"]

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in words]

print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# Original words: ['gitam', 'university', 'sunflower', 'beautiful']
# Stemmed words: ['gitam', 'univers', 'sunflow', 'beauti']

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
word = "foods"
lemma = lemmatizer.lemmatize(word, pos='n') # 'pos=n' specifies noun

print(f"Original word: {word}")
print(f"Lemmatized word: {lemma}")
# Out:
# Original word: foods
# Lemmatized word: food
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
